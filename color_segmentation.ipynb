# %%
import numpy as np
import os

# find parameters
path = "npz/"
path_list = os.listdir(path)
path_list.sort()
data = [[]] * 200
i = 0
for filename in path_list:
    #print(os.path.join(path,filename))
    data[i] = np.load(os.path.join(path,filename))
    i = i + 1

n = i

blue = [[0, 0, 0]]
brwn = [[0, 0, 0]]
orng = [[0, 0, 0]]
othr = [[0, 0, 0]]
ored = [[0, 0, 0]]
sred = [[0, 0, 0]]
    
for i in range(0, n):
    if (data[i]['COLOR_BLUE.npy'].size != 0):
        blue = np.concatenate((blue, data[i]['COLOR_BLUE.npy']), axis = 0)
    if (data[i]['COLOR_BROWN.npy'].size != 0):
        brwn = np.concatenate((brwn, data[i]['COLOR_BROWN.npy']), axis = 0)
    if (data[i]['COLOR_ORANGE.npy'].size != 0):
        orng = np.concatenate((orng, data[i]['COLOR_ORANGE.npy']), axis = 0)
    if (data[i]['COLOR_OTHER.npy'].size != 0):
        othr = np.concatenate((othr, data[i]['COLOR_OTHER.npy']), axis = 0)
    if (data[i]['COLOR_OTHER_RED.npy'].size != 0):
        ored = np.concatenate((ored, data[i]['COLOR_OTHER_RED.npy']), axis = 0)
    if (data[i]['COLOR_STOP_SIGN_RED.npy'].size != 0):
        sred = np.concatenate((sred, data[i]['COLOR_STOP_SIGN_RED.npy']), axis = 0)

blue = blue[1:len(blue),:]
brwn = brwn[1:len(brwn),:]
orng = orng[1:len(orng),:]
othr = othr[1:len(othr),:]
ored = ored[1:len(ored),:]
sred = sred[1:len(sred),:]

# prior
total = len(blue) + len(brwn) + len(orng) + len(othr) + len(ored) + len(sred)
prior_blue = len(blue) / total
prior_brwn = len(brwn) / total
prior_orng = len(orng) / total
prior_othr = len(othr) / total
prior_ored = len(ored) / total
prior_sred = len(sred) / total

# RGB
blue_mu = np.mean(blue, axis = 0)
brwn_mu = np.mean(brwn, axis = 0)
orng_mu = np.mean(orng, axis = 0)
othr_mu = np.mean(othr, axis = 0)
ored_mu = np.mean(ored, axis = 0)
sred_mu = np.mean(sred, axis = 0)

blue_cov = np.cov(np.transpose(blue))
brwn_cov = np.cov(np.transpose(brwn))
orng_cov = np.cov(np.transpose(orng))
othr_cov = np.cov(np.transpose(othr))
ored_cov = np.cov(np.transpose(ored))
sred_cov = np.cov(np.transpose(sred))

# %%
if color == 'RGB':
    print("        self.mu_blue = np.array([", blue_mu[0], ',', blue_mu[1], ',', blue_mu[2], '])')
    print("        self.mu_brwn = np.array([", brwn_mu[0], ',', brwn_mu[1], ',', brwn_mu[2], '])')
    print("        self.mu_orng = np.array([", orng_mu[0], ',', orng_mu[1], ',', orng_mu[2], '])')
    print("        self.mu_othr = np.array([", othr_mu[0], ',', othr_mu[1], ',', othr_mu[2], '])')
    print("        self.mu_ored = np.array([", ored_mu[0], ',', ored_mu[1], ',', ored_mu[2], '])')
    print("        self.mu_sred = np.array([", sred_mu[0], ',', sred_mu[1], ',', sred_mu[2], '])')

    print("        self.cov_blue = np.array([", blue_cov[0], ',', blue_cov[1], ',', blue_cov[2], '])')
    print("        self.cov_brwn = np.array([", brwn_cov[0], ',', brwn_cov[1], ',', brwn_cov[2], '])')
    print("        self.cov_orng = np.array([", orng_cov[0], ',', orng_cov[1], ',', orng_cov[2], '])')
    print("        self.cov_othr = np.array([", othr_cov[0], ',', othr_cov[1], ',', othr_cov[2], '])')
    print("        self.cov_ored = np.array([", ored_cov[0], ',', ored_cov[1], ',', ored_cov[2], '])')
    print("        self.cov_sred = np.array([", sred_cov[0], ',', sred_cov[1], ',', sred_cov[2], '])')

elif color == 'YCbCr':
    print("        self.mu_blue = np.array([", blue_mu_YCbCr[0], ',', blue_mu_YCbCr[1], ',', blue_mu_YCbCr[2], '])')
    print("        self.mu_brwn = np.array([", brwn_mu_YCbCr[0], ',', brwn_mu_YCbCr[1], ',', brwn_mu_YCbCr[2], '])')
    print("        self.mu_orng = np.array([", orng_mu_YCbCr[0], ',', orng_mu_YCbCr[1], ',', orng_mu_YCbCr[2], '])')
    print("        self.mu_othr = np.array([", othr_mu_YCbCr[0], ',', othr_mu_YCbCr[1], ',', othr_mu_YCbCr[2], '])')
    print("        self.mu_ored = np.array([", ored_mu_YCbCr[0], ',', ored_mu_YCbCr[1], ',', ored_mu_YCbCr[2], '])')
    print("        self.mu_sred = np.array([", sred_mu_YCbCr[0], ',', sred_mu_YCbCr[1], ',', sred_mu_YCbCr[2], '])')

    print("        self.cov_blue = np.array([", blue_cov_YCbCr[0], ',', blue_cov_YCbCr[1], ',', blue_cov_YCbCr[2], '])')
    print("        self.cov_brwn = np.array([", brwn_cov_YCbCr[0], ',', brwn_cov_YCbCr[1], ',', brwn_cov_YCbCr[2], '])')
    print("        self.cov_orng = np.array([", orng_cov_YCbCr[0], ',', orng_cov_YCbCr[1], ',', orng_cov_YCbCr[2], '])')
    print("        self.cov_othr = np.array([", othr_cov_YCbCr[0], ',', othr_cov_YCbCr[1], ',', othr_cov_YCbCr[2], '])')
    print("        self.cov_ored = np.array([", ored_cov_YCbCr[0], ',', ored_cov_YCbCr[1], ',', ored_cov_YCbCr[2], '])')
    print("        self.cov_sred = np.array([", sred_cov_YCbCr[0], ',', sred_cov_YCbCr[1], ',', sred_cov_YCbCr[2], '])')

print('        self.prior_blue =', prior_blue)
print('        self.prior_brwn =', prior_brwn)
print('        self.prior_orng =', prior_orng)
print('        self.prior_othr =', prior_othr)
print('        self.prior_ored =', prior_ored)
print('        self.prior_sred =', prior_sred)
# Out:
#         self.mu_blue = np.array([ 106.32696045284762 , 148.32640286906891 , 201.0777186347703 ])
#         self.mu_brwn = np.array([ 139.20916654606165 , 103.78299936072575 , 69.64969718192108 ])
#         self.mu_orng = np.array([ 169.14539134204188 , 116.81573704348986 , 80.89911553113981 ])
#         self.mu_othr = np.array([ 107.50309236401463 , 109.62905178793655 , 102.10582157175617 ])
#         self.mu_ored = np.array([ 115.36591420932713 , 57.02063770101015 , 61.38112578856563 ])
#         self.mu_sred = np.array([ 161.3237125352304 , 15.32027143124588 , 26.35305860237528 ])
#         self.cov_blue = np.array([ [2388.69912323 1913.3432948  1026.14991707] , [1913.3432948  1824.97852504 1123.98347644] , [1026.14991707 1123.98347644  952.17631369] ])
#         self.cov_brwn = np.array([ [4239.25522742 3138.90543003 1877.20749456] , [3138.90543003 2731.64375814 2053.14389894] , [1877.20749456 2053.14389894 2026.4131502 ] ])
#         self.cov_orng = np.array([ [2623.23266988 2572.15074572 1295.30603522] , [2572.15074572 3102.9567313  1738.07035391] , [1295.30603522 1738.07035391 1546.98883444] ])
#         self.cov_othr = np.array([ [3313.42772962 3099.95140829 3047.00924281] , [3099.95140829 3098.95577588 3065.13104889] , [3047.00924281 3065.13104889 3485.05804823] ])
#         self.cov_ored = np.array([ [2833.5241197   997.57205282  944.21663791] , [ 997.57205282 1432.21680477 1408.44684507] , [ 944.21663791 1408.44684507 1492.63410039] ])
#         self.cov_sred = np.array([ [2898.92219889  320.23672272  492.01529842] , [320.23672272 562.88347196 519.56228942] , [492.01529842 519.56228942 635.32527426] ])
#         self.prior_blue = 0.2568322410412888
#         self.prior_brwn = 0.06575565674834602
#         self.prior_orng = 0.0018280167650162158
#         self.prior_othr = 0.6595718676206456
#         self.prior_ored = 0.0011570577026393705
#         self.prior_sred = 0.014855160122063957

# %%
# single gaussian

# slower
def gaussian_(x, mu, sig):
    cov_inv = np.linalg.inv(sig)
    denominator = np.sqrt((2*np.pi)**3 * np.linalg.det(sig))
    exp = [0]*len(x)
    
    for i in range(len(x)):
        exp[i] = np.exp(-(np.dot(np.dot(x[i]-mu,cov_inv), np.transpose(x[i]-mu))) / 2)
        
    return exp / denominator

# faster
def gaussian(x, mu, sig):
    L = np.linalg.cholesky(np.linalg.inv(sig))
    expTerm = np.exp(-np.sum(np.square(np.dot(x-mu, L)), axis = 1) / 2)
    denominator = np.sqrt((2*np.pi)**3 * np.linalg.det(sig))
    return expTerm / denominator

# %%
# load image: done
def load_image(imgBGR, color):
    if color == 'RGB':
        img = cv2.cvtColor(imgBGR, cv2.COLOR_BGR2RGB)
    elif color == 'HSV':
        img = cv2.cvtColor(imgBGR, cv2.COLOR_BGR2HSV)
    else:
        img = cv2.cvtColor(imgBGR, cv2.COLOR_BGR2YCR_CB)

    pixels_array = np.reshape(img, (-1,3))
    return pixels_array

# %%
from skimage.measure import label, regionprops

class StopSignDetector():
    def __init__(self):
        self.prior_blue = prior_blue
        self.prior_brwn = prior_brwn
        self.prior_orng = prior_orng
        self.prior_othr = prior_othr
        self.prior_ored = prior_ored
        self.prior_sred = prior_sred
            
        if color == 'RGB':
            self.mu_blue = np.array(blue_mu)
            self.mu_brwn = np.array(brwn_mu)
            self.mu_orng = np.array(orng_mu)
            self.mu_othr = np.array(othr_mu)
            self.mu_ored = np.array(ored_mu)
            self.mu_sred = np.array(sred_mu)
            
            self.cov_blue = np.array(blue_cov)
            self.cov_brwn = np.array(brwn_cov)
            self.cov_orng = np.array(orng_cov)
            self.cov_othr = np.array(othr_cov)
            self.cov_ored = np.array(ored_cov)
            self.cov_sred = np.array(sred_cov)
        
        elif color == 'YCbCr':
            self.mu_blue = np.array(blue_mu_YCbCr)
            self.mu_brwn = np.array(brwn_mu_YCbCr)
            self.mu_orng = np.array(orng_mu_YCbCr)
            self.mu_othr = np.array(othr_mu_YCbCr)
            self.mu_ored = np.array(ored_mu_YCbCr)
            self.mu_sred = np.array(sred_mu_YCbCr)
            
            self.cov_blue = np.array(blue_cov_YCbCr)
            self.cov_brwn = np.array(brwn_cov_YCbCr)
            self.cov_orng = np.array(orng_cov_YCbCr)
            self.cov_othr = np.array(othr_cov_YCbCr)
            self.cov_ored = np.array(ored_cov_YCbCr)
            self.cov_sred = np.array(sred_cov_YCbCr)

    def segment_image(self, img):
        
        image_size = np.shape(img)
        test = load_image(img, color)
        
        # claculate gaussian probability
        p_blue = gaussian(test, self.mu_blue, self.cov_blue) * prior_blue
        p_brwn = gaussian(test, self.mu_brwn, self.cov_brwn) * prior_brwn
        p_orng = gaussian(test, self.mu_orng, self.cov_orng) * prior_orng
        p_othr = gaussian(test, self.mu_othr, self.cov_othr) * prior_othr
        p_ored = gaussian(test, self.mu_ored, self.cov_ored) * prior_ored
        p_sred = gaussian(test, self.mu_sred, self.cov_sred) * prior_sred
        
        # choose the max and output the mask
        max_p = list(map(max, zip(p_blue, p_brwn, p_orng, p_othr, p_ored, p_sred)))
        mask_img = 255*np.array(max_p == p_sred).astype('uint8')
        mask_img = mask_img.reshape(image_size[:2])
        
        # Closing (morphology), erode first and dilate
        kernel = np.ones((10,10), np.uint8)
        mask_img = cv2.morphologyEx(mask_img, cv2.MORPH_CLOSE, kernel)
        
        # Opening (morphology), erode first and dilate
        kernel = np.ones((5,5), np.uint8)
        mask_img = cv2.morphologyEx(mask_img, cv2.MORPH_OPEN, kernel)
        
        return mask_img

    def get_bounding_box(self, img):

        image_size = np.shape(img)
        mask_img = self.segment_image(img)
        
        boxes = []
        labels = label(mask_img)
        regions = regionprops(labels)
        for r in regions:
            score = 0
            minr, minc, maxr, maxc = r.bbox
            h = maxr - minr
            w = maxc - minc
            a = r.area
            e = r.extent
            er = r.euler_number
            
            if h/w > 0.5 and h/w < 2:
                score = score + 2
            if h/w > 0.9 and h/w < 1.2:
                score = score + 3
             
            if e > 0.45 and e < 0.85:
                score = score + 3
            if a > 9000 and e > 0.55 and e < 0.75:
                score = score + 3   
            if a > 500 and a < 9000 and e > 0.72 and e < 0.85:
                score = score + 3
            
            if er < 0:
                score = score + 5;
            if score > 10:
                boxes.append([minc, image_size[0]-maxr, maxc, image_size[0]-minr])
            
            print("area :", a)
            print("e    :", e)
            print("er   :", er)
            print("score:", score)
        
        sorted(boxes, key = lambda x:(x[0]))
        
        return boxes

# %%
# main function

import numpy as np
import os, cv2

color = 'RGB'
folder = "validation"
my_detector = StopSignDetector()
for filename in os.listdir(folder):
    
    image = cv2.imread(os.path.join(folder,filename))
    
    # resize image
    if image.shape[1] > image.shape[0]:
        w = 1000;
        h = int(image.shape[0] * 1000 / image.shape[1])
    else:
        h = 1000;
        w = int(image.shape[1] * 1000 / image.shape[0])
        
    dim = (w, h)
    img = cv2.resize(image, dim, interpolation = cv2.INTER_AREA)
    
    # cv2.imshow('image', img)
    # cv2.waitKey(1)
    # cv2.destroyAllWindows()
    image_size = np.shape(img)
    mask_img = my_detector.segment_image(img)
    boxes = my_detector.get_bounding_box(img)
    print(boxes)
    print(filename)
    print("-----------------")

    box_img = []
    for i in range(len(boxes)):
        box_img = cv2.rectangle(img, (boxes[i][0],image_size[0]-boxes[i][1]), (boxes[i][2],image_size[0]-boxes[i][3]), (0, 255, 0) , 2)

    cv2.imshow('mask', mask_img)
    cv2.waitKey(3)
    cv2.imwrite(os.path.join("result_mask", filename), mask_img)

    if len(box_img) > 0:
        cv2.imshow('box', box_img)
        cv2.waitKey(1)
        cv2.imwrite(os.path.join("result_box", filename), box_img)
    else:
        cv2.imwrite(os.path.join("result_box", filename), image)

cv2.waitKey(1)
cv2.destroyAllWindows()
# Out:
# area : 12712
# e    : 0.3923577888206426
# er   : -69
# score: 10
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 6
# e    : 0.5
# er   : 1
# score: 3
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 43
# e    : 0.5308641975308642
# er   : 1
# score: 8
# area : 13
# e    : 0.4642857142857143
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 4
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 3
# e    : 1.0
# er   : 1
# score: 0
# area : 636
# e    : 0.8217054263565892
# er   : 1
# score: 6
# area : 7
# e    : 0.875
# er   : 1
# score: 0
# area : 7
# e    : 0.5833333333333334
# er   : 1
# score: 3
# area : 4
# e    : 0.6666666666666666
# er   : 1
# score: 5
# area : 2
# e    : 0.5
# er   : 1
# score: 8
# area : 21
# e    : 0.5833333333333334
# er   : 1
# score: 3
# area : 85
# e    : 0.5448717948717948
# er   : 0
# score: 8
# area : 131
# e    : 0.5848214285714286
# er   : 0
# score: 8
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 0.5
# er   : 1
# score: 8
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 3
# e    : 1.0
# er   : 1
# score: 0
# area : 18
# e    : 0.6428571428571429
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 15
# e    : 0.6
# er   : 1
# score: 8
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 3
# e    : 0.75
# er   : 1
# score: 8
# area : 18
# e    : 0.6428571428571429
# er   : 1
# score: 3
# area : 3
# e    : 0.75
# er   : 1
# score: 8
# area : 60
# e    : 0.4166666666666667
# er   : 1
# score: 2
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 4
# e    : 0.6666666666666666
# er   : 1
# score: 5
# area : 5
# e    : 0.625
# er   : 1
# score: 3
# area : 3
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 4
# e    : 0.6666666666666666
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 24
# e    : 0.34285714285714286
# er   : 1
# score: 2
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 3
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 10
# e    : 0.8333333333333334
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# []
# 10.jpg
# -----------------
# area : 1212
# e    : 0.5605920444033302
# er   : -3
# score: 13
# area : 28
# e    : 0.8484848484848485
# er   : 1
# score: 3
# area : 5
# e    : 0.8333333333333334
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 6
# e    : 1.0
# er   : 1
# score: 0
# area : 14
# e    : 0.5384615384615384
# er   : 1
# score: 3
# area : 23
# e    : 0.8846153846153846
# er   : 1
# score: 0
# area : 209
# e    : 0.8196078431372549
# er   : 0
# score: 8
# area : 13
# e    : 0.7222222222222222
# er   : 1
# score: 3
# area : 4
# e    : 0.6666666666666666
# er   : 1
# score: 5
# area : 7
# e    : 0.875
# er   : 1
# score: 0
# area : 3
# e    : 1.0
# er   : 1
# score: 0
# area : 3
# e    : 1.0
# er   : 1
# score: 0
# area : 11
# e    : 0.4583333333333333
# er   : 1
# score: 3
# area : 72
# e    : 0.6923076923076923
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# [[513, 505, 559, 552]]
# 100.jpg
# -----------------
# area : 50
# e    : 0.5208333333333334
# er   : 1
# score: 5
# area : 91
# e    : 0.364
# er   : 1
# score: 0
# area : 4
# e    : 1.0
# er   : 1
# score: 5
# area : 8
# e    : 0.6666666666666666
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 538
# e    : 0.5828819068255688
# er   : -4
# score: 8
# area : 53
# e    : 0.8833333333333333
# er   : 1
# score: 0
# area : 32
# e    : 0.8
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 9
# e    : 0.42857142857142855
# er   : 1
# score: 0
# area : 21
# e    : 0.84
# er   : 1
# score: 8
# area : 59
# e    : 0.6145833333333334
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# []
# 171.jpg
# -----------------
# area : 110548
# e    : 0.5471318980450384
# er   : -23
# score: 13
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 11
# e    : 0.6875
# er   : 1
# score: 8
# area : 10
# e    : 0.8333333333333334
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 829
# e    : 0.37975263398992215
# er   : 1
# score: 2
# area : 27
# e    : 0.36
# er   : 1
# score: 0
# area : 4
# e    : 0.6666666666666666
# er   : 1
# score: 5
# area : 3825
# e    : 0.8201114922813036
# er   : 1
# score: 6
# area : 1393
# e    : 0.8711694809255784
# er   : 1
# score: 5
# area : 23
# e    : 0.6571428571428571
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 15
# e    : 0.75
# er   : 1
# score: 5
# area : 6
# e    : 0.75
# er   : 1
# score: 3
# area : 3
# e    : 1.0
# er   : 1
# score: 0
# area : 938
# e    : 0.5193798449612403
# er   : -3
# score: 13
# area : 591
# e    : 0.3420138888888889
# er   : -1
# score: 7
# area : 4
# e    : 0.6666666666666666
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 252
# e    : 0.4032
# er   : 1
# score: 5
# area : 5
# e    : 0.625
# er   : 1
# score: 3
# area : 28
# e    : 0.36363636363636365
# er   : 1
# score: 2
# area : 3
# e    : 0.75
# er   : 1
# score: 8
# area : 942
# e    : 0.6061776061776062
# er   : -1
# score: 10
# area : 68
# e    : 0.5714285714285714
# er   : 1
# score: 3
# area : 174
# e    : 0.58
# er   : 1
# score: 3
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 42
# e    : 0.75
# er   : 1
# score: 5
# area : 23
# e    : 0.92
# er   : 1
# score: 5
# area : 133
# e    : 0.8209876543209876
# er   : 1
# score: 3
# [[388, 204, 837, 654], [954, 217, 997, 259]]
# 18.jpg
# -----------------
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 54
# e    : 0.54
# er   : 1
# score: 3
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# []
# 22.png
# -----------------
# area : 37202
# e    : 0.6485930471773772
# er   : -5
# score: 16
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1262
# e    : 0.8481182795698925
# er   : 1
# score: 6
# area : 452
# e    : 0.8932806324110671
# er   : 1
# score: 5
# [[725, 317, 966, 555]]
# 3.jpg
# -----------------
# area : 27
# e    : 0.675
# er   : 1
# score: 3
# area : 4
# e    : 0.4444444444444444
# er   : 1
# score: 5
# area : 18
# e    : 0.72
# er   : 1
# score: 8
# area : 196
# e    : 0.3769230769230769
# er   : 1
# score: 2
# area : 15
# e    : 0.75
# er   : 1
# score: 5
# area : 18
# e    : 0.72
# er   : 1
# score: 8
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 19
# e    : 0.6333333333333333
# er   : 1
# score: 5
# area : 12
# e    : 0.75
# er   : 1
# score: 8
# area : 67
# e    : 0.67
# er   : 1
# score: 8
# area : 35
# e    : 0.4166666666666667
# er   : 1
# score: 0
# area : 37
# e    : 0.5138888888888888
# er   : 1
# score: 8
# area : 186
# e    : 0.7530364372469636
# er   : 0
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 46
# e    : 0.4791666666666667
# er   : 1
# score: 5
# area : 13
# e    : 0.5416666666666666
# er   : 1
# score: 3
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# []
# 33.jpg
# -----------------
# area : 266
# e    : 0.4
# er   : -1
# score: 7
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 6
# e    : 0.375
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 5
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 10
# e    : 0.4166666666666667
# er   : 1
# score: 0
# area : 4
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 6
# e    : 1.0
# er   : 1
# score: 0
# area : 10
# e    : 0.7142857142857143
# er   : 1
# score: 3
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 4
# e    : 0.6666666666666666
# er   : 1
# score: 5
# area : 7
# e    : 0.4375
# er   : 1
# score: 5
# area : 5
# e    : 0.5
# er   : 1
# score: 3
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 6
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 7
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 3
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 3
# e    : 1.0
# er   : 1
# score: 0
# area : 4
# e    : 0.6666666666666666
# er   : 1
# score: 5
# area : 5
# e    : 0.625
# er   : 1
# score: 3
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 31
# e    : 0.2818181818181818
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 3
# e    : 0.5
# er   : 1
# score: 5
# area : 5
# e    : 0.5555555555555556
# er   : 1
# score: 8
# area : 2
# e    : 0.5
# er   : 1
# score: 8
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 6
# e    : 1.0
# er   : 1
# score: 2
# area : 4
# e    : 1.0
# er   : 1
# score: 5
# area : 3
# e    : 0.75
# er   : 1
# score: 8
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 6
# e    : 0.6
# er   : 1
# score: 3
# area : 2
# e    : 0.5
# er   : 1
# score: 8
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 11
# e    : 0.55
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 3
# e    : 0.75
# er   : 1
# score: 8
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 0.5
# er   : 1
# score: 8
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 15
# e    : 0.5357142857142857
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 3
# e    : 0.5
# er   : 1
# score: 5
# area : 2
# e    : 0.5
# er   : 1
# score: 8
# area : 2
# e    : 0.5
# er   : 1
# score: 8
# area : 446
# e    : 0.15128900949796473
# er   : -8
# score: 7
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 3
# e    : 1.0
# er   : 1
# score: 0
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 13
# e    : 0.5416666666666666
# er   : 1
# score: 3
# area : 4
# e    : 1.0
# er   : 1
# score: 0
# area : 18
# e    : 0.8181818181818182
# er   : 1
# score: 3
# area : 3
# e    : 1.0
# er   : 1
# score: 0
# area : 47
# e    : 0.41228070175438597
# er   : -1
# score: 5
# area : 11
# e    : 0.55
# er   : 1
# score: 3
# area : 9
# e    : 0.75
# er   : 1
# score: 3
# area : 62
# e    : 0.27555555555555555
# er   : 0
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 22
# e    : 0.5641025641025641
# er   : 1
# score: 3
# area : 10
# e    : 0.5555555555555556
# er   : 1
# score: 3
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 6
# e    : 0.5
# er   : 1
# score: 5
# area : 5
# e    : 0.5555555555555556
# er   : 1
# score: 8
# area : 7
# e    : 0.3888888888888889
# er   : 1
# score: 0
# area : 3
# e    : 0.75
# er   : 1
# score: 8
# area : 11
# e    : 0.6111111111111112
# er   : 1
# score: 3
# area : 15
# e    : 0.3
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 12
# e    : 0.42857142857142855
# er   : 1
# score: 2
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 9
# e    : 0.45
# er   : 1
# score: 2
# area : 6
# e    : 0.5
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 5
# e    : 0.5
# er   : 1
# score: 3
# area : 21
# e    : 0.6
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 6
# e    : 0.75
# er   : 1
# score: 3
# area : 7
# e    : 0.5833333333333334
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 5
# e    : 1.0
# er   : 1
# score: 0
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 6
# e    : 0.6
# er   : 1
# score: 3
# area : 3
# e    : 0.75
# er   : 1
# score: 8
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 10
# e    : 0.47619047619047616
# er   : 1
# score: 3
# area : 53
# e    : 0.5408163265306123
# er   : 0
# score: 3
# area : 5
# e    : 0.625
# er   : 1
# score: 3
# area : 13
# e    : 1.0
# er   : 1
# score: 0
# area : 4
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 11
# e    : 0.55
# er   : 1
# score: 5
# area : 4
# e    : 0.5
# er   : 1
# score: 3
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 4
# e    : 1.0
# er   : 1
# score: 0
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 0.5
# er   : 1
# score: 8
# area : 3
# e    : 1.0
# er   : 1
# score: 0
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 3
# e    : 0.75
# er   : 1
# score: 8
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 3
# e    : 0.5
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 3
# e    : 0.75
# er   : 1
# score: 8
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 7865
# e    : 0.6026819923371648
# er   : -6
# score: 10
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 3
# e    : 1.0
# er   : 1
# score: 0
# area : 243
# e    : 0.7714285714285715
# er   : 1
# score: 3
# area : 85
# e    : 0.8673469387755102
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 3
# e    : 0.75
# er   : 1
# score: 8
# area : 4
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 4
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 3
# e    : 1.0
# er   : 1
# score: 0
# area : 15
# e    : 0.75
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 11
# e    : 0.3142857142857143
# er   : 1
# score: 2
# area : 5
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 3
# e    : 1.0
# er   : 1
# score: 0
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 18
# e    : 0.75
# er   : 1
# score: 3
# area : 3
# e    : 0.5
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 33
# e    : 0.4583333333333333
# er   : 1
# score: 5
# area : 4
# e    : 0.6666666666666666
# er   : 1
# score: 5
# area : 74
# e    : 0.578125
# er   : 1
# score: 3
# area : 4
# e    : 0.6666666666666666
# er   : 1
# score: 5
# area : 67
# e    : 0.319047619047619
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 11
# e    : 0.6111111111111112
# er   : 1
# score: 3
# area : 7
# e    : 0.7777777777777778
# er   : 1
# score: 8
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 20
# e    : 0.5714285714285714
# er   : 1
# score: 5
# area : 4
# e    : 0.5
# er   : 1
# score: 3
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 0.5
# er   : 1
# score: 8
# area : 3
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 4
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 3
# e    : 1.0
# er   : 1
# score: 0
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 3
# e    : 0.5
# er   : 1
# score: 5
# area : 3
# e    : 1.0
# er   : 1
# score: 0
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 0.5
# er   : 1
# score: 8
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 3
# e    : 0.75
# er   : 1
# score: 8
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 3
# e    : 0.5
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 3
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# []
# 37.jpg
# -----------------
# area : 417
# e    : 0.5346153846153846
# er   : 1
# score: 5
# area : 9
# e    : 1.0
# er   : 1
# score: 5
# area : 504
# e    : 0.586046511627907
# er   : 1
# score: 3
# []
# 50.jpg
# -----------------
# area : 33591
# e    : 0.5869679178024743
# er   : -3
# score: 16
# area : 865
# e    : 0.7355442176870748
# er   : 1
# score: 6
# area : 337
# e    : 0.8140096618357487
# er   : 1
# score: 5
# area : 92
# e    : 0.4107142857142857
# er   : 1
# score: 5
# area : 18
# e    : 1.0
# er   : 1
# score: 0
# area : 6
# e    : 1.0
# er   : 1
# score: 2
# area : 12
# e    : 0.6
# er   : 1
# score: 5
# area : 14
# e    : 1.0
# er   : 1
# score: 0
# area : 12
# e    : 0.48
# er   : 1
# score: 8
# area : 5
# e    : 0.5555555555555556
# er   : 1
# score: 8
# area : 4
# e    : 1.0
# er   : 1
# score: 5
# area : 11
# e    : 0.7333333333333333
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 8
# e    : 0.5
# er   : 1
# score: 8
# area : 3
# e    : 0.75
# er   : 1
# score: 8
# area : 4
# e    : 1.0
# er   : 1
# score: 5
# area : 1053
# e    : 0.13295454545454546
# er   : 1
# score: 5
# area : 38
# e    : 0.4222222222222222
# er   : 1
# score: 0
# area : 5
# e    : 0.8333333333333334
# er   : 1
# score: 5
# area : 4
# e    : 1.0
# er   : 1
# score: 5
# area : 29
# e    : 0.37662337662337664
# er   : 1
# score: 2
# area : 1199
# e    : 0.45160075329566857
# er   : -1
# score: 10
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 4
# e    : 0.6666666666666666
# er   : 1
# score: 5
# area : 16
# e    : 0.6666666666666666
# er   : 1
# score: 5
# area : 5
# e    : 1.0
# er   : 1
# score: 0
# area : 12
# e    : 0.8571428571428571
# er   : 1
# score: 0
# area : 112
# e    : 0.5
# er   : 1
# score: 8
# area : 52
# e    : 1.0
# er   : 1
# score: 0
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 18
# e    : 0.9
# er   : 1
# score: 2
# area : 690
# e    : 0.3942857142857143
# er   : 1
# score: 0
# area : 99
# e    : 0.66
# er   : 1
# score: 5
# area : 4
# e    : 0.6666666666666666
# er   : 1
# score: 5
# area : 20
# e    : 0.4444444444444444
# er   : 1
# score: 2
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 7248
# e    : 0.41835497835497837
# er   : -5
# score: 7
# area : 5
# e    : 1.0
# er   : 1
# score: 0
# area : 1240
# e    : 0.31794871794871793
# er   : 1
# score: 0
# area : 33
# e    : 0.4714285714285714
# er   : 1
# score: 3
# area : 4
# e    : 1.0
# er   : 1
# score: 5
# area : 4
# e    : 1.0
# er   : 1
# score: 5
# area : 44
# e    : 0.4583333333333333
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 5
# e    : 1.0
# er   : 1
# score: 0
# area : 3
# e    : 1.0
# er   : 1
# score: 0
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 26
# e    : 0.5777777777777777
# er   : 1
# score: 5
# area : 4
# e    : 1.0
# er   : 1
# score: 5
# area : 324
# e    : 0.25
# er   : 1
# score: 0
# area : 10
# e    : 1.0
# er   : 1
# score: 0
# area : 34
# e    : 0.4722222222222222
# er   : 1
# score: 5
# area : 39
# e    : 0.4642857142857143
# er   : 1
# score: 3
# area : 3
# e    : 0.75
# er   : 1
# score: 8
# area : 6
# e    : 0.75
# er   : 1
# score: 3
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 47
# e    : 0.4351851851851852
# er   : 1
# score: 0
# area : 7
# e    : 0.4375
# er   : 1
# score: 5
# area : 4
# e    : 1.0
# er   : 1
# score: 5
# area : 4
# e    : 1.0
# er   : 1
# score: 5
# area : 4
# e    : 1.0
# er   : 1
# score: 5
# area : 6
# e    : 1.0
# er   : 1
# score: 2
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 10
# e    : 1.0
# er   : 1
# score: 0
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 4
# e    : 1.0
# er   : 1
# score: 5
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 939
# e    : 0.6310483870967742
# er   : 1
# score: 3
# area : 6
# e    : 1.0
# er   : 1
# score: 2
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 4
# e    : 1.0
# er   : 1
# score: 5
# area : 6
# e    : 1.0
# er   : 1
# score: 2
# area : 10
# e    : 0.5
# er   : 1
# score: 5
# area : 22
# e    : 0.5238095238095238
# er   : 1
# score: 8
# area : 4
# e    : 1.0
# er   : 1
# score: 5
# area : 6
# e    : 1.0
# er   : 1
# score: 2
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 8
# e    : 1.0
# er   : 1
# score: 0
# area : 4
# e    : 1.0
# er   : 1
# score: 5
# area : 30
# e    : 0.24793388429752067
# er   : 1
# score: 5
# area : 55
# e    : 0.6547619047619048
# er   : 1
# score: 5
# area : 4
# e    : 1.0
# er   : 1
# score: 5
# area : 5
# e    : 1.0
# er   : 1
# score: 0
# area : 8
# e    : 0.5
# er   : 1
# score: 8
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 11
# e    : 0.7857142857142857
# er   : 1
# score: 3
# area : 19
# e    : 0.76
# er   : 1
# score: 8
# [[146, 308, 397, 536]]
# 6.jpg
# -----------------
# area : 10085
# e    : 0.5946344339622641
# er   : -6
# score: 13
# area : 124
# e    : 0.8266666666666667
# er   : 1
# score: 5
# area : 320
# e    : 0.8
# er   : 1
# score: 3
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 20
# e    : 0.5714285714285714
# er   : 1
# score: 5
# area : 1316
# e    : 0.40617283950617283
# er   : -1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 75
# e    : 0.625
# er   : 1
# score: 5
# area : 14
# e    : 0.7
# er   : 1
# score: 5
# area : 6
# e    : 0.6666666666666666
# er   : 1
# score: 8
# area : 8339
# e    : 0.6184825335607802
# er   : -5
# score: 10
# area : 297
# e    : 0.7941176470588235
# er   : 1
# score: 3
# area : 113
# e    : 0.8692307692307693
# er   : 1
# score: 2
# area : 2
# e    : 0.5
# er   : 1
# score: 8
# [[200, 720, 306, 880]]
# 68.jpg
# -----------------
# area : 1049
# e    : 0.5429606625258799
# er   : 1
# score: 8
# area : 23
# e    : 0.7666666666666667
# er   : 1
# score: 3
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# []
# 79.jpg
# -----------------
# area : 705
# e    : 0.6283422459893048
# er   : -2
# score: 13
# area : 654
# e    : 0.6005509641873278
# er   : -2
# score: 13
# area : 20
# e    : 0.8333333333333334
# er   : 1
# score: 3
# area : 5
# e    : 0.8333333333333334
# er   : 1
# score: 5
# area : 19
# e    : 0.7916666666666666
# er   : 1
# score: 3
# area : 4
# e    : 0.6666666666666666
# er   : 1
# score: 5
# [[784, 347, 818, 380], [239, 342, 272, 375]]
# 92.jpg
# -----------------
# area : 868
# e    : 0.821969696969697
# er   : 1
# score: 11
# area : 1531
# e    : 0.3738705738705739
# er   : 1
# score: 5
# area : 1567
# e    : 0.36526806526806527
# er   : 1
# score: 5
# area : 24
# e    : 1.0
# er   : 1
# score: 2
# area : 17
# e    : 0.85
# er   : 1
# score: 2
# area : 1479
# e    : 0.696
# er   : 1
# score: 3
# area : 740
# e    : 0.578125
# er   : 1
# score: 5
# area : 1110
# e    : 0.7429718875502008
# er   : 1
# score: 6
# area : 500
# e    : 0.7352941176470589
# er   : 1
# score: 3
# area : 576
# e    : 0.5841784989858012
# er   : 1
# score: 3
# area : 182
# e    : 0.5947712418300654
# er   : 1
# score: 8
# area : 81
# e    : 0.9529411764705882
# er   : 1
# score: 0
# area : 23
# e    : 0.9583333333333334
# er   : 1
# score: 2
# area : 16
# e    : 0.38095238095238093
# er   : 1
# score: 2
# area : 19
# e    : 0.6785714285714286
# er   : 1
# score: 5
# area : 32
# e    : 0.48484848484848486
# er   : 1
# score: 5
# area : 3
# e    : 0.75
# er   : 1
# score: 8
# area : 49
# e    : 0.7
# er   : 1
# score: 3
# area : 45
# e    : 0.6923076923076923
# er   : 1
# score: 3
# area : 70
# e    : 0.5555555555555556
# er   : 1
# score: 3
# area : 87
# e    : 0.8285714285714286
# er   : 1
# score: 3
# area : 441
# e    : 0.665158371040724
# er   : 1
# score: 3
# area : 27
# e    : 0.7714285714285715
# er   : 1
# score: 5
# area : 547
# e    : 0.4781468531468531
# er   : 1
# score: 5
# area : 103
# e    : 0.8046875
# er   : 1
# score: 3
# area : 7
# e    : 0.7777777777777778
# er   : 1
# score: 8
# area : 1114
# e    : 0.4086573734409391
# er   : 0
# score: 0
# area : 37
# e    : 0.6166666666666667
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 5
# e    : 1.0
# er   : 1
# score: 0
# area : 8
# e    : 0.6666666666666666
# er   : 1
# score: 5
# area : 24209
# e    : 0.3905181313717899
# er   : -17
# score: 7
# area : 4
# e    : 1.0
# er   : 1
# score: 5
# area : 4
# e    : 1.0
# er   : 1
# score: 0
# area : 920
# e    : 0.6084656084656085
# er   : 0
# score: 3
# area : 3474
# e    : 0.6211335598069014
# er   : 0
# score: 3
# area : 62
# e    : 0.7380952380952381
# er   : 1
# score: 3
# area : 3
# e    : 1.0
# er   : 1
# score: 0
# area : 16
# e    : 0.6666666666666666
# er   : 1
# score: 3
# area : 24
# e    : 0.8888888888888888
# er   : 1
# score: 0
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 4
# e    : 1.0
# er   : 1
# score: 0
# area : 287
# e    : 0.5035087719298246
# er   : 0
# score: 3
# area : 280
# e    : 0.5072463768115942
# er   : -3
# score: 13
# area : 39
# e    : 0.6190476190476191
# er   : 1
# score: 5
# area : 3385
# e    : 0.4636986301369863
# er   : -17
# score: 8
# area : 480
# e    : 0.44077134986225897
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 600
# e    : 0.48115477145148355
# er   : 0
# score: 5
# area : 193
# e    : 0.5361111111111111
# er   : 1
# score: 5
# area : 4
# e    : 1.0
# er   : 1
# score: 0
# area : 3
# e    : 0.75
# er   : 1
# score: 8
# area : 4
# e    : 0.5
# er   : 1
# score: 3
# area : 2
# e    : 1.0
# er   : 1
# score: 0
# area : 12
# e    : 0.75
# er   : 1
# score: 8
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 27
# e    : 0.9642857142857143
# er   : 1
# score: 2
# area : 3
# e    : 0.75
# er   : 1
# score: 8
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 13
# e    : 0.5416666666666666
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 126
# e    : 0.6
# er   : 1
# score: 3
# area : 3
# e    : 1.0
# er   : 1
# score: 0
# area : 3
# e    : 1.0
# er   : 1
# score: 0
# area : 14
# e    : 0.56
# er   : 1
# score: 8
# area : 6
# e    : 1.0
# er   : 1
# score: 2
# area : 18
# e    : 0.75
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 75
# e    : 0.6198347107438017
# er   : 1
# score: 8
# area : 257
# e    : 0.3386034255599473
# er   : -1
# score: 7
# area : 315
# e    : 0.45454545454545453
# er   : 1
# score: 5
# area : 80
# e    : 0.5194805194805194
# er   : 1
# score: 3
# area : 225
# e    : 0.36
# er   : 1
# score: 5
# area : 6
# e    : 1.0
# er   : 1
# score: 2
# area : 253
# e    : 0.4791666666666667
# er   : 1
# score: 8
# area : 59
# e    : 0.5267857142857143
# er   : 1
# score: 5
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 33
# e    : 0.673469387755102
# er   : 1
# score: 8
# area : 1
# e    : 1.0
# er   : 1
# score: 5
# area : 8
# e    : 0.6666666666666666
# er   : 1
# score: 5
# area : 55
# e    : 0.873015873015873
# er   : 0
# score: 2
# [[249, 908, 281, 941], [99, 71, 123, 94]]
# 93.png
# -----------------
